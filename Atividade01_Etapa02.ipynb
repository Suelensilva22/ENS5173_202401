# %% [markdown]
# # AULA 03 - PYTHON
# Nesta aula veremos:
#
#  1. Numpy arrays e pandas Dataframes
#  2. Open and export files
#  3. Conditional Statements
#  4. Loops em Python
#  5. Functions - def

# %%
import numpy as np #importando a biblioteca NumPy com o nome np 

# Criando um vetor de dados aleatórios
data = np.random.rand(1000,2) #cria uma matriz NumPy com 1000 linhas e 2 colunas chamada "data", onde cada elemento é um número aleatório entre 0 e 1

# Verificando o tamanho do vetor
print(data.shape) #escreve a forma da matriz "data"
print(np.size(data)) #escreve o número total de elementos na matriz "data"

# Print de uma amostra dos dados
print(data[0:10]) #acessando da linha 0 até a Linha 9 (10 primeiras linhas da matriz)
print(data[0:10].shape) #retorna a forma (shape) de uma fatia da matriz "data"
# Out:
# (1000, 2)
# 2000
# [[0.60087431 0.58491691]
#  [0.78377435 0.51671961]
#  [0.37828621 0.81364184]
#  [0.25090729 0.46429195]
#  [0.37296226 0.60323818]
#  [0.1344814  0.24384305]
#  [0.80919236 0.28036295]
#  [0.30479865 0.75430984]
#  [0.38881624 0.10700902]
#  [0.16493861 0.76655483]]
# (10, 2)

# %%
# Usando Monte-Carlo
dataMax = 1000 #Definindo a variável "dataMax"
dataMin = 10 #Definindo a variável "dataMin"
data = (dataMax - dataMin)*data + dataMin #escala os valores da matriz "data" para o intervalo entre "dataMin" e "dataMax"
print(data[0:10]) #acessando da linha 0 até a Linha 9 (10 primeiras linhas da matriz) depois da transformação
# Out:
# [[604.86556209 589.06773879]
#  [785.93660677 521.55241321]
#  [384.5033506  815.50541696]
#  [258.39821821 469.64902855]
#  [379.23263953 607.20579422]
#  [143.13658972 251.40462245]
#  [811.10043906 287.55931876]
#  [311.75066387 756.76674211]
#  [394.92808219 115.93893345]
#  [173.28922389 768.88927685]]

# %%
import matplotlib.pyplot as plt #importa a biblioteca Matplotlib para criação de gráficos em Python

fig, ax = plt.subplots(3) #cria uma figura com 3 subplots (é uma função em Matplotlib que é usada para criar várias áreas de plotagem em uma única figura) organizados em uma coluna
ax[0].plot(data) #plota todos os dados
ax[1].plot(data[:,0]) #plota apenas a primeira coluna
ax[2].plot(data[:,1]) #plta apenas a segunda coluna
print(type(data)) #escreve o tipo da variável 'data'
# Out:
# <class 'numpy.ndarray'>

# %%
# Criando um dado 2D 
data3d = np.sin(np.random.rand(1000,1000)) #cria uma matriz NumPy 1000x1000 e calcula o seno para cada elemento dessa matriz, armazenando o resultado na variável "data3d"
print(data3d) #escrever a matriz "data3d"
# Out:
# [[0.04358731 0.79288419 0.09345337 ... 0.14757497 0.33589546 0.11706623]
#  [0.56571841 0.70245354 0.76846842 ... 0.64552178 0.67823921 0.20756943]
#  [0.81166769 0.67597115 0.74707884 ... 0.18412575 0.31993696 0.7211714 ]
#  ...
#  [0.2276637  0.21098036 0.63269256 ... 0.6002254  0.75204893 0.57693126]
#  [0.16168    0.52434539 0.40551724 ... 0.37554201 0.59675009 0.09211776]
#  [0.67272774 0.6026381  0.08763527 ... 0.32350834 0.49521239 0.0951642 ]]

# %%
# Plotando um dado 3D
fig2, ax2 = plt.subplots() # cria um novo subplot (um espaço para plotagem) e armazena a figura e o eixo correspondente nas variáveis fig2 e ax2
ax2.pcolor(data3d) #criar um gráfico de mapa de cores 2D a partir dos dados contidos na matriz "data3d"

# %%
# Criando vertor temporal
dtime = np.arange(np.datetime64("2022-01-01"), np.datetime64("2023-01-01"), np.timedelta64(1, "h")) #cria uma variedade de datas e horas utilizando o NumPy, começa em "2022-01-01" e termina em "2023-01-01" (intervalos de uma hora)
print(dtime[1:10]) #mostra as datas e horas a partir da segunda (índice 1) até a décima (índice 9) na variável "dtime"
print(dtime.shape) #mostra quantos elementos tem na variável "dtime"
print(type(dtime)) #escrever o tipo de variável é "dtempo".
# Out:
# ['2022-01-01T01' '2022-01-01T02' '2022-01-01T03' '2022-01-01T04'
#  '2022-01-01T05' '2022-01-01T06' '2022-01-01T07' '2022-01-01T08'
#  '2022-01-01T09']
# (8760,)
# <class 'numpy.ndarray'>

# %% [markdown]
# ## Pandas

# %%
import pandas as pd #importando a biblioteca Pandas com o nome pd 

df = pd.DataFrame() #criando um dataframe (quadro de dados) utilizando a biblioteca pandas chamado "df"

# %%
df['datetime'] = dtime #monstrando um dataframe onde a variável dtime é atribuida à coluna "datetime" do "df"

# %%
df['random'] = np.random.rand(df.shape[0]) #criando uma nova coluna chamada "random" no "df" e preenche essa coluna com valores aleatórios gerados pela função "np.random.rand()" com base no número de linhas do DataFrame

# %%
df['random'][1:10] #acessa as linhas de índice 1 a 9 na coluna "random" do "df"
# Out:
# 1    0.399390
# 2    0.838691
# 3    0.836343
# 4    0.681446
# 5    0.381774
# 6    0.726245
# 7    0.343747
# 8    0.729092
# 9    0.820561
# Name: random, dtype: float64

# %%
# Indexação
df.iloc[:,0] #seleciona todas as linhas da primeira coluna do "df" utilizando indexação baseada em posição
# Out:
# 0      2022-01-01 00:00:00
# 1      2022-01-01 01:00:00
# 2      2022-01-01 02:00:00
# 3      2022-01-01 03:00:00
# 4      2022-01-01 04:00:00
#                ...
# 8755   2022-12-31 19:00:00
# 8756   2022-12-31 20:00:00
# 8757   2022-12-31 21:00:00
# 8758   2022-12-31 22:00:00
# 8759   2022-12-31 23:00:00
# Name: datetime, Length: 8760, dtype: datetime64[s]

# %%
# Colocando o datetime como index
df = df.set_index(df['datetime']) #redefine o índice do "df" para a coluna "datetime", ou seja, os valores dessa coluna se tornam os índices do DataFrame.
df #o DataFrame "df" será exibido com a coluna "datetime" como seu índice
# Out:
#                                datetime    random
# datetime
# 2022-01-01 00:00:00 2022-01-01 00:00:00  0.585622
# 2022-01-01 01:00:00 2022-01-01 01:00:00  0.399390
# 2022-01-01 02:00:00 2022-01-01 02:00:00  0.838691
# 2022-01-01 03:00:00 2022-01-01 03:00:00  0.836343
# 2022-01-01 04:00:00 2022-01-01 04:00:00  0.681446
# ...                                 ...       ...
# 2022-12-31 19:00:00 2022-12-31 19:00:00  0.340600
# 2022-12-31 20:00:00 2022-12-31 20:00:00  0.977045
# 2022-12-31 21:00:00 2022-12-31 21:00:00  0.866980
# 2022-12-31 22:00:00 2022-12-31 22:00:00  0.462248
# 2022-12-31 23:00:00 2022-12-31 23:00:00  0.667238
#
# [8760 rows x 2 columns]

# %%
# Criando colunas com ano, mês e dia
df['year'] = df.index.year #criando a coluna ano
df['month'] = df.index.month #criando a coluna mês
df['day'] = df.index.day #criando a coluna dia

#os valores dessas colunas são extraídos do índice do DataFrame, que foi definido anteriormente como a coluna "datetime"

# %%
tt = np.arange(0,df.shape[0],1) #cria uma sequência tt de números inteiros de 0 ao número de linhas no "df"
print(tt.shape) #mostra quantos elementos tem na variável "tt"
df['sazonal'] = (np.cos(tt/(360*4))) #cria uma coluna sazonal no "df" utilizando a função cosseno (np.cos) aplicada à sequência tt, gerando uma componente sazonal
df['timeSeries'] = 10*df['sazonal']+df['random'] #cria uma coluna "timeSeries" no "df", que é a combinação da componente sazonal multiplicada por 10 e a coluna random
#df['sazonal'].plot()
df['timeSeries'].plot(color='red') #plota a coluna "timeSeries" em um gráfico de linha com a cor vermelha.
# Out:
# (8760,)
# <Axes: xlabel='datetime'>

# %%
df #o DataFrame "df" será exibido
# Out:
#                                datetime    random  year  month  day   sazonal  \
# datetime
# 2022-01-01 00:00:00 2022-01-01 00:00:00  0.585622  2022      1    1  1.000000
# 2022-01-01 01:00:00 2022-01-01 01:00:00  0.399390  2022      1    1  1.000000
# 2022-01-01 02:00:00 2022-01-01 02:00:00  0.838691  2022      1    1  0.999999
# 2022-01-01 03:00:00 2022-01-01 03:00:00  0.836343  2022      1    1  0.999998
# 2022-01-01 04:00:00 2022-01-01 04:00:00  0.681446  2022      1    1  0.999996
# ...                                 ...       ...   ...    ...  ...       ...
# 2022-12-31 19:00:00 2022-12-31 19:00:00  0.340600  2022     12   31  0.979401
# 2022-12-31 20:00:00 2022-12-31 20:00:00  0.977045  2022     12   31  0.979541
# 2022-12-31 21:00:00 2022-12-31 21:00:00  0.866980  2022     12   31  0.979680
# 2022-12-31 22:00:00 2022-12-31 22:00:00  0.462248  2022     12   31  0.979819
# 2022-12-31 23:00:00 2022-12-31 23:00:00  0.667238  2022     12   31  0.979958
#
# ...

# %%
df.to_csv(r'C:\Users\Suelen Silva\Documents\CONTROLE_24.1\ENS5173_202401\dados\brutos\noise_2022.csv') # Salvar meu dataframe

# %%
# Criando uma função

def noiseCreation(path, year): #função que aceita dois parâmetros: caminho e ano
    """Esta função cria um ruido com sazonalidade.
    Inputs:
        path = asdasdas
        year = asdasdasdas

    Criado por Suelen
    """

    df = pd.DataFrame() #criando um dataframe (quadro de dados) utilizando a biblioteca pandas chamado "df"
    
    dtime = np.arange(np.datetime64(str(year)+"-01-01"), np.datetime64(str(year+1)+"-01-01"), np.timedelta64(1, "h")) # Criando vertor temporal
    
    df['datetime'] = dtime # Monstrando um dataframe
    
    df = df.set_index(df['datetime']) # Datetime como index do dataframe
    
    # Criando colunas com ano, mês e dia
    df['year'] = df.index.year #criando a coluna ano
    df['month'] = df.index.month #criando a coluna mês
    df['day'] = df.index.day #criando a coluna dia

    #os valores dessas colunas são extraídos do índice do DataFrame, que foi definido anteriormente como a coluna "datetime"

    df['random'] = np.random.rand(df.shape[0]) # Crio uma coluna random

    # Adicionar sazonalidade
    tt = np.arange(0,df.shape[0],1)
    print(tt.shape)
    df['sazonal'] = (np.cos(tt/(360*4)))
    df['timeSeries'] = 10*df['sazonal']+df['random']
    #df['sazonal'].plot()
    df['timeSeries'].plot(color='red')
    df.to_csv(path+'/noise_'+str(year)+'.csv') #cria um arquivo CSV chamado noise_ano.csv no caminho especificado, onde ano é substituído pela variável "year"
    
    return df

# %%
path = r'C:\Users\Suelen Silva\Documents\CONTROLE_24.1\ENS5173_202401\dados\brutos' #define um caminho de arquivo
df2 = noiseCreation(path,2050) #chama a função "noiseCreation" com esse caminho e o ano de 2050 como argumentos
# Out:
# (8760,)

# %%
# Primeira opção de loop
for ii in range(2002,2010): #cria um loop que itera sobre os anos de 2002 a 2009
    print(ii) #mostrar para cada valor de ii no intervalo especificado 
    df = noiseCreation(path,ii) #chama a função "noiseCreation" para cada ano no intervalo especificado
# Out:
# 2002
# (8760,)
# 2003
# (8760,)
# 2004
# (8784,)
# 2005
# (8760,)
# 2006
# (8760,)
# 2007
# (8760,)
# 2008
# (8784,)
# 2009
# (8760,)

# %%
df #o DataFrame "df" será exibido
# Out:
#                                datetime  year  month  day    random   sazonal  \
# datetime
# 2009-01-01 00:00:00 2009-01-01 00:00:00  2009      1    1  0.544720  1.000000
# 2009-01-01 01:00:00 2009-01-01 01:00:00  2009      1    1  0.669668  1.000000
# 2009-01-01 02:00:00 2009-01-01 02:00:00  2009      1    1  0.724708  0.999999
# 2009-01-01 03:00:00 2009-01-01 03:00:00  2009      1    1  0.767276  0.999998
# 2009-01-01 04:00:00 2009-01-01 04:00:00  2009      1    1  0.963235  0.999996
# ...                                 ...   ...    ...  ...       ...       ...
# 2009-12-31 19:00:00 2009-12-31 19:00:00  2009     12   31  0.801958  0.979401
# 2009-12-31 20:00:00 2009-12-31 20:00:00  2009     12   31  0.832772  0.979541
# 2009-12-31 21:00:00 2009-12-31 21:00:00  2009     12   31  0.815624  0.979680
# 2009-12-31 22:00:00 2009-12-31 22:00:00  2009     12   31  0.540703  0.979819
# 2009-12-31 23:00:00 2009-12-31 23:00:00  2009     12   31  0.709922  0.979958
#
# ...

# %%
anos = [2001,2030,2032,2053,2060]

for ano in anos: #para o ano no intervalo "anos" temos:
    print(ano) #mostrar ano para cada valor na lista "anos"
    if ano > 2030: #para ano maior que 2030 temos:
        df = noiseCreation(path,ano) 

#garante que a função noiseCreation seja chamada apenas para anos maiores que 2030
# Out:
# 2001
# 2030
# 2032
# (8784,)
# 2053
# (8760,)
# 2060
# (8784,)

# %%
import os 
files = os.listdir(path) #utiliza o módulo "os" para listar os arquivos em um determinado diretório especificado pelo caminho "path"
print(files) #listar todos os arquivos e diretórios no caminho especificado pela variável "path"

allData = []
for file in files:
    if file.endswith('.csv'): #irá ler todos os arquivos CSV no diretório especificado pelo caminho "path"
        print(file) #listar todos os arquivos e diretórios no caminho 
        data = pd.read_csv(path+'/'+file) #lê o arquivo CSV especificado e armazena os dados lidos em um DataFrame chamado "dados"
        allData.append(data) #esse DataFrame é adicionado à lista allData
        
#Este processo é repetido para cada arquivo CSV no diretório especificado pelo caminho "path".
# Out:
# ['noise_2002.csv', 'noise_2003.csv', 'noise_2004.csv', 'noise_2005.csv', 'noise_2006.csv', 'noise_2007.csv', 'noise_2008.csv', 'noise_2009.csv', 'noise_2022.csv', 'noise_2032.csv', 'noise_2050.csv', 'noise_2053.csv', 'noise_2060.csv']
# noise_2002.csv
# noise_2003.csv
# noise_2004.csv
# noise_2005.csv
# noise_2006.csv
# noise_2007.csv
# noise_2008.csv
# noise_2009.csv
# noise_2022.csv
# noise_2032.csv
# noise_2050.csv
# noise_2053.csv
# noise_2060.csv

# %%
allDataDf = pd.concat(allData) #cria um novo DataFrame chamado "allDataDf", que contém todos os dados dos DataFrames individuais armazenados na lista "allData"

# %%
allDataDf #mostra todos os dados do DataFrame "allDataDf"
# Out:
#                  datetime           datetime.1  year  month  day    random  \
# 0     2002-01-01 00:00:00  2002-01-01 00:00:00  2002      1    1  0.098943
# 1     2002-01-01 01:00:00  2002-01-01 01:00:00  2002      1    1  0.919588
# 2     2002-01-01 02:00:00  2002-01-01 02:00:00  2002      1    1  0.746601
# 3     2002-01-01 03:00:00  2002-01-01 03:00:00  2002      1    1  0.707743
# 4     2002-01-01 04:00:00  2002-01-01 04:00:00  2002      1    1  0.658181
# ...                   ...                  ...   ...    ...  ...       ...
# 8779  2060-12-31 19:00:00  2060-12-31 19:00:00  2060     12   31  0.673489
# 8780  2060-12-31 20:00:00  2060-12-31 20:00:00  2060     12   31  0.515509
# 8781  2060-12-31 21:00:00  2060-12-31 21:00:00  2060     12   31  0.208359
# 8782  2060-12-31 22:00:00  2060-12-31 22:00:00  2060     12   31  0.854588
# 8783  2060-12-31 23:00:00  2060-12-31 23:00:00  2060     12   31  0.273307
#
#        sazonal  timeSeries
# 0     1.000000   10.098943
# ...

# %%
plt.plot(allDataDf['datetime'],allDataDf['timeSeries']) #plota os dados da coluna "timeSeries" em função da coluna "datetime"
